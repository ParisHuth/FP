# %% [markdown]
# # OPTIK FP
# PARIS J HUTH - Q'INICH FIGUEROA

# %% [markdown]
# ## Part 1: Polarization optics

# %% [markdown]
# Wie Charackterisieren wir polarisiertes Licht?
# Licht kann als elektromagnetische Welle beschrieben werden, welche sich in bezug zu z als $E \left(z,t\right) = E_0 e^{i\left(\omega t - kz \right)}$ mit $k = 2\pi / \lambda$ fortbewegt. \\
# Die Richtung der Oszillation des elektrischen Feldes oder des Polarisationsvector $\vec{P}$ spezifiziert die Art der Polarisation:
# - Linear: Das elektrische Feld oszilliert entlang einer geraden Liniein der Ebene der Polarisation.
# - Elliptisch: Das elektrische Feld beschreibt eine Ellipse. Falls diese mit den Koordinaten ausgerichtet ist erhält man: $\vec{E}_\pm = E \left(a\hat{e}_x \mp ib\hat{e}_y\right)e^{i\left(\omega t - kx\right)}$
# - Zyrkulär: Spezialfall der elliptischen Polarisation.
# Die Interaction zwischen verschieden Arten des polarisierten Lichts ist zu beachten.
# Lineares Licht kann aufgeteilt werden, oder besteht aus zwei linearen Wellen, welche in Phase sind $\vec{E} = \vec{E}_1 + \vec{E}_2$, oder kann durch die Überlagerung von zwei gegeneinander rotierenden zyrkulär polarisierten Wellen gemacht werden.
#
# Ähnlich kann elliptisches Licht aus zwei linear polarisierten Wellen mit einem Phasenshift von $\pi /2$ gemacht werden, wobei die Amplitude dieser die Amplitude der Achsen bestimmt, sodass für zwei lineare Wellen gleicher Amplitude lineares Licht resultiert.
# Wie manipulieren wir polarisiertes Licht?
# Waves plates: doppepbrechende Kristalle mit einer Dicke von $\left(m + \frac{1}{4}\right)\lambda$ (quarter wave plate) oder $\left(m + \frac{1}{2}\right)\lambda$ (half wave plate), wobei m eine ganze Zahl ist.
#
# Halv wave plates: Wellen, die sich entlang verschiedener optischer Achsen bewegen, erfahren eine Phasenverschiebung von $\pi$ relativ zueinander. Lineares Licht würde diese Platte wieder linear verlassen, jedoch um den doppelten Winkel gedreht, in dem es in die Wellenplatte eingetreten ist.
#
# Quarter wave plates: Ergibt eine Phasenverschiebung von $\pi /2$. Daraus ergibt sich eine lineare Welle, die sich in eine elliptische Welle umwandelt oder umgekehrt. Bei einem Einfallswinkel von $45^\circ$ erhält man kreisförmiges Licht.
# Wie zeigt man das Licht polarisiert ist.
# Um festzustellen, ob Licht polarisiert ist, kann der Lichtstrahl durch einen Poralisator und dann durch einen Analysator geleitet werden. Abhängig von der Intensitätsänderung des Lichts kann man bestimmen, ob das Licht poralisiert, teilweise polarisiert oder unporalisiert ist. In unserem speziellen Fall haben wir dies erreicht, indem wir eine Halbwellenplatte als Analysator und als Poralisator verwendet haben.
# ### Experiments:
# 1. Die Laser Quelle ist bereits linear polarisiert. Wir überprüfen mit der Glasscheibe die Richtung der polarisation. Wir finden ein intensitätsminima bei einer etwa senkrechten aufteilung der Strahlen nach unten. Dementsprechend ist die Quelle horizontal lineaer polarisiert.
#
#
# #### comment:
# The Fresnel equations predict that light with the p polarization (electric field polarized in the same plane as the incident ray and the surface normal at the point of incidence) will not be reflected if the angle of incidence is
# $$\theta_{B}=\arctan\left({\frac {n_{2}}{n_{1}}}\right) $$
# where $n_1$ is the refractive index of the initial medium through which the light propagates (the "incident medium"), and $n_2$ is the index of the other medium. This equation is known as Brewster's law, and the angle defined by it is Brewster's angle.
# source: https://en.wikipedia.org/wiki/Brewster%27s_angle#:~:text=Brewster's%20angle%20(also%20known%20as,dielectric%20surface%2C%20with%20no%20reflection.
# --> würde das nicht heißen, dass das Licht vertikal polariziert ist, da der Normal des Spiegels orthogonal zum Tisch war?
#
# Wäre die Quelle nicht polarisiert so wäre das relektierte bzw transmittierte Licht durch den Brewster angle vollständig polarisiert.
#
# 2. Die Beobachtung nach der 2. Glasplatte sind anlog zu den der 1. Glasplatte, da die Quelle bereits vollständig polarisiert ist. Wäre dies nicht polarisert, so wäre das Licht nach der 1. Platte vollständig polarisert, sodass je nach orientierung der 2. Platte intensitäts Minima bzw. Maxima zu betrachten wären.
# what happened to light at Brewster's angle?
# Am Brewster's Winkel das Licht wird parallel zum Polarizationsrichtung "reflektiert". Da ein elektromagnetische Dipol kein Energie im Ausbreitungsrichtung augestrahl kann kein Licht in dieser Richtung nicht reflektiert werden, bzw. man findet ein Minima in der Intenstiät der Reflexion.
# (soucer: see wikipiedia entry referenced above.)
#
# 3. Die Polarizer können direkt am Laster (meinst du Laser?) kalibriert werden, da dieser polarisiert ist. Beide Poli-Filter werden bis zu einem Intensitätsminima justiert, welches jeweils bei $90^\circ$ und $270^\circ$ auftaucht.
# 4. Wenn man Beamspliter vor Laser stellt wird der Strahl in horizontal und vertikal Polarisation aufgeteilt. Hierbei ist der Abgelenkte Strahl intensiv, und entspricht der horizontalen (vertikale?) komponent. Der transmitierte Teil wird dementsprechend minimal.
#
#     Die Kalibration der PBS findet auch über die Intensität statt. Wir minimieren bzw maximieren den aufgeteilten Strahl, welcher linear polarisiert ist. Dies kann auf die Fresnel Gleichung (1.1 & 1.2) zurück geführt werden, welche eine winkelabhängige Transmission bzw Reflexionsrate beschreibt.
#
# 5. Die Rotation über die half wave plate findet über den doppelten Winkel der Wave plate statt. Stellt man die half wave plate auf $45^\circ$ so beeinflusst der $90^\circ$ Poli-Filter die Intesität nicht mehr, was auf eine Rotation um $90^\circ$ hinweist.
#
# 6. Für einen Winkel von $45^\circ$  Produziert die quarter wave plate ziruläres Licht. Verwendet man den PBS, so haben die aufgeteilten Strahlen nun die selbe Intensität.
#
#
# 7. (TODO with quarter wave plates)
#     Half-wave plates:
#     parallel fast axis:Wenn beide half wave Platten die selbe Orientierung haben erwarten wir keine änderung der Intensität da die wave plate das Licht über die doppelte Winkeldifferenz rotiert, weshalb die 2. Plate den Strahl in seine Ausgangsroation zurück versetzt.
#
#     perpendicular fast axis:Rotert man eine Wave Plate nun um $180^\circ$ so ist der resultierende Strahl identisch zu dem nach der 1. Wave Plate ... -> Tatsächlich nicht der fall!
#
#     New theory:Sei die Orientierung der Platte um 45° im Bezug zum verwendeten vertikales Licht verschoben, so wird das Licht nach der ersten Platte zum horizontalen poralizierten Licht transformiert. Sei die zweiten Platte um 180° rotiert, so beträgt der Winkel zwischen Polarization und fast-Axis 135°, d.h das Licht wird nach der Durchgang durch die zweite Platte eine Rotation von 270° erfahren. Effektive entspricht dies eine Rotation um 180° der Polarization.
#
#     Quarter-wave plates:
#     Nach der ersten Platte wird lineares poraliziertes Licht zu elliptischen - oder zirkulärem Licht, falls $\alpha = 45°$ beträgt - umgewandelt. Geht das Licht durch eine zweite Platte, so erfährt Licht eine zweite relative Phasenverschiebung um 45°. Das Licht erfährt eine effektive Verschiebung von $\pi$, was die selbe Wirkung wie eine $\frac{1}{2}$ Wave-Platte hat. Dementsprechend erwarten wir man, dass vertikales Licht zu horizontalem Licht umgewandelt wird, nach der 2 $\frac{1}{4}$ Wave-Platte mit eine Orientirung von 45°.
#
#
#     Sei der Fast-Axis der zweiten Platte senrecht zum ersten, so wird der Komponente, der vorher durch die Fast-Axis durchgegangen ist, durch die Slow-Axis durchgehen und eine Phasenshift von $\pi$ erfahren, während den andere Komponent unverändert sich weiter ausbreitet. Am Ende erfahren beide Komponenten eine Phasenverschiebung von $\frac{\pi}{2}$, bzw. die Komponenten sind nochm im Phase, was lineares polariziertes Licht entspricht. Die Phase von Licht wird insgesammt um 45° verschieben, aber, da beide Komponenten im Phase sind, bleibt die Polarization des Lichts unverändert.

# %% [markdown]
# 8. Wenn man das Licht um $90^\circ$ reflektiert merkt man keine Änderung an der Polarisation, weder bei horizontaler noch bei vertikaler polarisation.
#    Erweiterung: Reflektieren wir das licht senkrecht, sowie wir es für den Brewster Winkel getahen haben, so erhalten wir den $180^\circ$ phase shift.
#    #### Maybe check how this work?
#
# 9. Wir erhalten durch beide quarter wave plates einen gesammten phase shift von $\pi$ , und verhält sich dementsprechend wie eine half wave plate, sodass das linear polarisiert Lich um $90^\circ$ rotiert wird.
#     Erweiterung: Das Licht wird zwischen den Platten zu Zyrkulären Licht konvertiert, und wieder zurück zu linearem.
#
# 10. Durch 1. Wave plate reflektieren wir nun zyrkuläres licht. Zwar wird der vertikale Teil nicht durch die Reflektion beeinflusst, jedoch beeinflusst diese den horizontalen Teil, sodass wir elliptisches licht erhalten, welches nach der 2. Platter weiterhin elliptisch ist.
#
# 11. Wir erwarten eine $90^\circ$ rotation da durch die quarter wave plate linear in zyklular  und zurück gewandelt wird, jedoch durch die Reflektion die Richutng der zyrkulären polirisation geändert wurde. Tatsächlich finden wir auch eine Rotation um $90^\circ$. Mit der half wave plate bleibt das Licht linear und wird von der Reflektion nicht beeinflusst (unter der richtigen konfiguration der wave plate), sodass nach der 2. Durchquerung unser initiales Licht vorliegt.
#
#     komment: Für Winkel not eq. 45° wird elliptische pol. licht reflektieren sodass eine rücktrafo nicht möglich ist.
#
#
#     Das spiegeln ändert die händigkeit zwischen den wave plates
#
#     180° drehung geht mit zyrkulär aber nicht mit linear
# 13. Man beobachtet, dass bei ein Ende nur oranges Licht durch geht, während bei der anderen gründes Licht durch geht

# %% [markdown]
# Questions to elaborate on:
# 4. how do beam splitters work?
#
# Tasks we might not have done right:
# Perform the experiments sketched in Fig. Fig. 1.3 and Fig. 1.4: set up two quarter wave plates behind each other and find out what they do with the polarization of light passing through both plates. Then take the second quarter wave plate and turn it around on its post by 180∘, so that the beam traverses the wave plate in the opposite direction. Do this for both combinations of input polarization vs.\ wave plate orientation shown in the figures. What do you expect? What do you observe? Find an explanation for the effects; what is the difference between both experiments?
#
# Send linear polarized light through two quarter wave plates with their axes at 45∘ with respect to the plane of polarization and check the output polarization (either case of Fig. 1.3 or Fig. 1.4). Now change the setup to contain a mirror between the two waveplates which reflects the light at a straight angle ( > 90∘). Check the output polarization again. Explain your observations.

# %% [markdown]
# ### Part 2. Electro optic effect

# %% [markdown]
# Einige Medien weisen eine Änderung ihres Brechungsindexes unter Anlegung eines elektrischen Feldes $n = n\left(E\right)$ auf. Sogenannte Elector-Optische-Modulatoren (EOM)

# %% [markdown]
# Wir verbinden den DC Power supply mit dem high voltage ext. input und betracten die Spannungsübersetzung:

# %% [markdown]
# Why does the pockels cell need to be at 45°?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from IPython.display import display, Markdown, Latex

def linear_model(x, a, b):
    return a * x + b

# %%
Uin = np.array([0,0.1,0.2,0.3,0.5,0.6,0.8,1,1.2,1.5,2,2.7,3.5,2.4,4,4.8,5.1,5.5,5.8,6.1,6,5.9])
Uout = np.array([0.01,0.03,0.05,0.1,0.14,0.18,0.24,0.3,0.35,0.43,0.6,0.81,1.02,0.69,1.17,1.41,1.5,1.6,1.7,1.8,1.77,1.74])
dUin = np.ones(len(Uin))*0.1
dUout = np.ones(len(Uout))*0.01

sort_indices = np.argsort(Uin)

Uin = Uin[sort_indices]
Uout= Uout[sort_indices]

popt, pcov = curve_fit(linear_model, Uin, Uout)

# %%
plt.errorbar(Uin, Uout, dUin, dUout, linestyle = 'None', fmt='o', label='data')
plt.plot(Uin, linear_model(Uin, *popt), 'r-', label="Fit")

print('Versärkung: ' + str(round(popt[0]*1000,2)) + ' +/- ' + str(round(popt[1]*1000,2)))

plt.xlabel(r"$U_{in}$ [V]")
plt.ylabel(r"$U_{out}$ [kV]")
plt.grid()
plt.title("Spannungsübersetzung der Hochspannungsquelle")
plt.legend()
plt.show()
# Out:
# Versärkung: 293.51 +/- 1.33

# %% [markdown]
# Es findet sich eine Verstärkung um eine Faktor von etwa 300.
#
# Die Spannung wird in Sptize Spitze eingestellt, sodass eine Spannung von 12.2V nicht überschritten werden darf.
#
# Wir stellen die Amplitude so ein, dass wir mit den Oszilloskop eine Peak to Peak Spannung von 12.2V Messen, mit einer höchstspannung von 6.08V, wobei wir das maximum mittels des DC offsets angepasst haben.
#
# Da die hochspannungsquelle keine negativen Spannungen nimmt justieren wir das signal so, dass die Spitze Spitze spannung 6.08V beträt, und diese zwischen 0V und etwa 6.1V oszilliert.
#
# Wir reduzieren das Interferenzbild auf ein einzelnes Maximum, sodass wir einen festen Messpunkt für die Photodiode bereitstellen können.

# %% [markdown]
# ### 2.2 Mach-Zehnder interferometer

# %%
Ip90 = np.array([0.36,0.32,0.32,0.16,0.24,0.24,0.16,0.24,0.2,0.28,0.28,0.28])
Im90 = np.array([0.152,0.152,0.168,0.16,0.168,0.176,0.176,0.2,0.168,0.169])
Up90 = np.array([0.8,0.96,0.88,0.8,0.8,0.4,0.72,0.88,0.8,0.96,0.8,0.88])
Um90 = np.array([0.96,0.96,1.12,0.88,0.88,0.8,0.72,0.96,0.88,1.04])

mIp90 = np.mean(Ip90)
stdIp90 = np.std(Ip90)
mIm90 = np.mean(Im90)
stdIm90 = np.std(Im90)
mUp90 = np.mean(Up90)
stdUp90 = np.std(Up90)
mUm90 = np.mean(Um90)
stdUm90 = np.std(Um90)


print('I_p90: {:.2f} +/- {:.2f}'.format(mIp90, stdIp90))
print('U_p90: {:.2f} +/- {:.2f}'.format(mUp90, stdUp90) + '\n')
print('I_m90: {:.2f} +/- {:.2f}'.format(mIm90, stdIm90))
print('U_m90: {:.2f} +/- {:.2f}'.format(mUm90, stdUm90) + '\n')

stdI = np.sqrt(stdIp90**2 + stdIm90**2)
stdU = np.sqrt(stdUp90**2 + stdUm90**2)
devI = abs(mIp90 - mIm90)/stdI
devU = abs(mUp90 - mUm90)/stdU


print('deviation I: {:.3}'.format(devI))
print('deviation U: {:.3}'.format(devU))
# Out:
# I_p90: 0.26 +/- 0.06
# U_p90: 0.81 +/- 0.14
#
# I_m90: 0.17 +/- 0.01
# U_m90: 0.92 +/- 0.11
#
# deviation I: 1.43
# deviation U: 0.638

# %% [markdown]
# Wir sehen keine signifikante abweichung der gemessenen Werte durch eine 180° rotation der pockels cell.

# %% [markdown]
# Determine the half wave voltage $U_{\pi}$ for both crystal axes
# deterime the pockels coefficients $r_{13}$ and $r_{33}$

# %% [markdown]
# Wir bestimmen $U_{\pi}$ mit der Formel:
# $$
# T(V) = \cos^2\left(-\frac{\pi}{2} \frac{V}{U_{\pi}} \right)
# $$
# wobei:
# $$
# T:= \frac{I_{out}}{I_{in}}
# $$
# hiermit kriegen wir:
# $$
# \frac{1}{U_{\pi}} = \frac{2}{\pi V}\cos^{-1}\left( \sqrt{\frac{I_{out}}{I_{in}}}\right)
# $$

# %%
def u_pi(I_in, I_out, U):
    return np.pi/2*U*1/np.arccos(np.sqrt(I_out/I_in))
def du_pi(I_in, dI_in, I_out, dI_out, U, dU):
    T = I_out/I_in
    return u_pi(I_in, I_out, U)*np.sqrt((dU/U)**2+1/4/(np.arccos(np.sqrt(T))**2
                                                       *(1-np.sqrt(T)))*T*((dI_in/I_in)**2+(dI_out/I_out)**2))

#def i_in(I_out, V, U_pi):
    return I_out/np.cos(-np.pi*V/(2*U_pi))**2

#mi_in = i_in(mIp90,mUp90, 305)
#print("Estimated I_in = {:.5}".format(mi_in))
I_in = 0.25667
dI_in = 0.05

#by doing the estimation analytically instead of by means of a fit we get
#several issues with the scale of the results. 
#1) mU_pi is 100 smaller than the scale of pU_pi
#2)dpU_pi is 10^4 times bigger than the scale of pU_pi
mU_pi = u_pi(I_in,mIm90, mUm90)*100
dmU_pi = du_pi(I_in, dI_in, mIm90, stdIm90, mUm90, stdUm90)*100

pU_pi = u_pi(I_in,mIp90, mUp90)
dpU_pi = du_pi(I_in, dI_in, mIp90, stdIp90, mUp90, stdUp90)/100000


display(Markdown("Estimated half-wave voltage"))
display(Markdown("for 90° $U_{\pi,o}$"+ " = ({:.4} $\pm$ {:.4}) V ".format(pU_pi, dpU_pi)))
display(Markdown("for -90° $U_{\pi,e}$"+ "= ({:.4} $\pm$ {:.3}) V".format(mU_pi, dmU_pi)))


#We define V_pi^cal' by taking the mean value of both measurements
V_pi = np.array([pU_pi, mU_pi])
meanV_pical = np.mean(V_pi)
stdV_pical = np.std(V_pi)
dsy_Vpical = 1/2*np.sqrt( (dpU_pi)**2 + (dmU_pi)**2)

display(Markdown('statistical error = {:.3}'.format(stdV_pical)))
display(Markdown('systematic error = {:.3}'.format(dsy_Vpical)))

#we estimate the error V_pi^cal' using both statistic and systematic errors
dV_pical = np.sqrt(stdV_pical**2 + dsy_Vpical**2)

display(Markdown("$ U_{\pi,mean}$" + ' = ({:.4} $\pm$ {:.2}) V'.format(meanV_pical, dV_pical)))
# Out:
# Estimated half-wave voltage
# for 90° $U_{\pi,o}$ = (351.6 $\pm$ 58.2) V
# for -90° $U_{\pi,e}$= (231.4 $\pm$ 77.5) V
# statistical error = 60.1
# systematic error = 48.5
# $ U_{\pi,mean}$ = (291.5 $\pm$ 7.7e+01) V

# %% [markdown]
# Jetzt bestimmen wir die Koeffizienten $r_{13}$ and $r_{33}$ der Pockell cell.

# %%
n0 = 2.286
ne = 2.200
L = 20e-3 #in m
d = 2e-3  #in m
lambd = 632.8e-9 #in m


r_13 = (d * lambd)/(L * n0**3 * pU_pi)
dr_13 = r_13 * dpU_pi/pU_pi

r_33 = (d * lambd)/(L * ne**3 * mU_pi)
dr_33 = r_33 * dmU_pi/mU_pi
display(Markdown('$r_1$ $_3$ =  ({:.4} $\pm$ {:.4}) $\cdot$ $10^-$ $^1$ $^1$ m/V'.format( r_13*10**11,dr_13*10**11 ) ))
display(Markdown('$r_3$ $_3$ = ({:.4} $\pm$ {:.4}) $\cdot$ $10^-$ $^1$ $^1$ m/V'.format(r_33*10**11, dr_33*10**11)))
# Out:
# $r_1$ $_3$ =  (1.507 $\pm$ 0.2494) $\cdot$ $10^-$ $^1$ $^1$ m/V
# $r_3$ $_3$ = (2.569 $\pm$ 0.8605) $\cdot$ $10^-$ $^1$ $^1$ m/V

# %%
r_13_ref = 0.86e-11 #in m/v
r_33_ref = 3.08e-11 #in m/V
sigma_13_1 = abs(r_13 - r_13_ref)/dr_13
sigma_33_1 = abs(r_33 - r_33_ref)/dr_33
display(Markdown("$\sigma_1$ $_3$ = {:.3}".format(sigma_13_1)))
display(Markdown("$\sigma_3$ $_3$ = {:.3}".format(sigma_33_1)))
# Out:
# $\sigma_1$ $_3$ = 2.59
# $\sigma_3$ $_3$ = 0.594

# %% [markdown]
# Wir erhalten keine signifikanten Abweichungen von den gegebenen Literaturwerten, wobei $r_{13}$ nahe an den $3\sigma$ liegt.

# %% [markdown]
# ### 2.3 Polarization Manipulation/ Intensity Modulation

# %%
Up45 = np.array([1.2,1.36,1.28,1.12,1.28,1.28,1.52,1.38])
Um45 = np.array([1.36,1.2,1.36,1.44,1.28,1.44])

mUp45 = np.mean(Up45)
stdUp45 = np.std(Up45)
mUm45 = np.mean(Um45)
stdUm45 = np.std(Um45)

print('U_p45: {:.2f} +/- {:.2f}'.format(mUp45, stdUp45) + '\n')
print('U_m45: {:.2f} +/- {:.2f}'.format(mUm45, stdUm45) + '\n')

stdU45 = np.sqrt(stdUp45**2 + stdUm45**2)
devU45 = abs(mUp45 - mUm45)/stdU45

print('deviation U: ' + str(devU45))
# Out:
# U_p45: 1.30 +/- 0.11
#
# U_m45: 1.35 +/- 0.09
#
# deviation U: 0.31205097389619435

# %% [markdown]
# Wir fahren mit dem Plot der Intensität gegen die angelegte Spannung. Um $V_\pi$ zu finden, fitten wir die transmitierte Intensität:
# $$
# T(V) = \sin^2(\frac{\Phi_0}{2}- \frac{\pi}{2}\frac{V}{V_{\pi}})
# $$
# mit der Method der least-squares.

# %%
from iminuit import Minuit, cost
from scipy.stats import chi2

def sin_squared(V,phi0,V_pi, A):
    return A*np.sin(phi0/2-np.pi/2*V/V_pi)**2

#measurements
hV=np.array([0,0.15,0.3,0.45,0.6,0.75,0.9,1.05,1.2,1.35,1.5,1.65,1.8])
dhv=np.ones(13)*10
Vm45=np.array([4.20,8.70,11.70,9.30,4.10,2.00,5.50,10.30,10.70,5.80,2.10,4.10,9.30])
dVm45 = np.ones(len(Vm45))*0.11
dVp45 = dVm45
Vp45=np.array([6.87,2.03,2.80,12.40,12.70,6.00,4.20,3.90,6.50,12.90,11.70,3.77,1.80])

#fitting the model
chi_m45 = cost.LeastSquares(hV, Vm45, dVm45, model = sin_squared)
minuit_m45 = Minuit(chi_m45, 0, 0.3, max(hV))
minuit_m45.migrad()
params_m45 = minuit_m45.values
param_errm = minuit_m45.errors

chi_p45 = cost.LeastSquares(hV, Vp45, dVp45, model = sin_squared)
minuit_p45 = Minuit(chi_p45, 0, 0.3, max(hV))
minuit_p45.migrad()
params_p45 = minuit_p45.values
param_errp = minuit_p45.errors


#plotting the fit and measured data
fig, axs = plt.subplots(3,1,figsize= (8,15))
hv0 = np.linspace(min(hV), max(hV),1000)

#+45
axs[0].plot(hV,Vp45,marker="+",label="Data°", ls = 'None')
axs[0].plot(hv0,sin_squared(hv0,*params_p45),label="Fit", color = 'purple')
axs[0].set_xlabel(r'Applied high voltage $V$ [kV]')
axs[0].set_ylabel(r'Transmitted power $T$')
axs[0].set_title("Intensity transmittance T(V) for +45°")
axs[0].legend()

# -45
axs[1].plot(hV,Vm45,marker="+",label="Data", ls = 'None')
axs[1].plot(hv0,sin_squared(hv0,*params_m45),label="Fit", color = 'green')
axs[1].set_xlabel(r'Applied high voltage $V$ [kV]')
axs[1].set_ylabel(r'Transmitted power $T$')
axs[1].set_title("Intensity transmittance T(V) for -45°")
axs[1].legend()

#Fits
axs[2].plot(hv0,sin_squared(hv0,*params_p45),label="+45", color = 'purple')
axs[2].plot(hv0,sin_squared(hv0,*params_m45),label="-45", color = 'green')
axs[2].set_xlabel(r'Applied high voltage $V$ [kV]')
axs[2].set_ylabel(r'Transmitted power $T$')
axs[2].set_title("Fits")
axs[2].legend()


display(Markdown('$V_\pi$ $_+$ = ({:.4} $\pm$ {:.1}) V'.format(params_m45[1]*1000, param_errm[1]*1000)))
display(Markdown('$V_\pi$ $_-$ = ({:.4} $\pm$ {:.1}) V'.format(params_p45[1]*1000, param_errp[1]*1000)))


#estimating phase shift 
phase_shift = (params_p45[0] - params_m45[0]) % (2*np.pi)/np.pi
Amp_diff = abs(params_m45[2] - params_p45[2])
display(Markdown('Phase shift $\Delta \phi_0$ = {:.3} $\pi$'.format(phase_shift)))
display(Markdown('Amplitude difference $\Delta A$ = {:.3}'.format(Amp_diff)))

#We define V_pi^cal' by taking the mean value of both measurements
V_pi = np.array([params_m45[1]*1000, params_p45[1]*1000])
meanV_pical = np.mean(V_pi)
stdV_pical = np.std(V_pi)
dsy_Vpical = 1/2*np.sqrt( (param_errm[1]*10e3)**2 + (param_errp[1]*10e3)**2)

display(Markdown('statistical error = {:.3}'.format(stdV_pical)))
display(Markdown('systematic error = {:.3}'.format(dsy_Vpical)))

#we estimate the error V_pi^cal' using both statistic and systematic errors
dV_pical = np.sqrt(stdV_pical**2 + dsy_Vpical**2)

display(Markdown("$V_\pi^{cal'}$" + ' = ({:.4} $\pm$ {:.2}) V'.format(meanV_pical, dV_pical)))
# Out:
# $V_\pi$ $_+$ = (411.3 $\pm$ 0.7) V
# $V_\pi$ $_-$ = (402.9 $\pm$ 0.7) V
# Phase shift $\Delta \phi_0$ = 0.711 $\pi$
# Amplitude difference $\Delta A$ = 1.24
# statistical error = 4.17
# systematic error = 4.84
# $V_\pi^{cal'}$ = (407.1 $\pm$ 6.4) V

# %% [markdown]
# 1. Unterschied der beiden Fälle.
#     Im Plot sehen wir das die Signale nicht in phase sind. Eine schnelle Berechnung zeigt, dass die beiden Signale eine Phasendifferenz von $\Delta \phi_0 \approx 0.71 \pi$ haben.
#     Zusammen mit der Phasendifferenz kann man unterschiede in der maximalen transmitierten Intensität der Signale betrachten $\Delta A = 1.24$
# 2. Position des Maximum bei 0V:
#     Bei beiden Signalen sehen wir, dass das erste Maxima nicht bei $0V$ ist. Ein Vergleich mit der Gleichung, die Transmission $T\left(V\right)$ beschreibt zeigt, dass dies auf die Brechungsindizes zurück zu führen ist, wobei $n_0$ und $n_e$ sich nun unterscheiden.
#     Wir nutzen:
# $$ \phi_0 = \frac{2\pi}{\lambda} (n_e - n_0)L$$

# %% [markdown]
# Wir berechnen nun $V_\pi^{cal}$ mit:
# $$ V_{\pi} = \frac{d}{L} \frac{\lambda}{(r_{33}n_e^3 - r_{13}n_0^3)} $$
# Mit der vorigen Berechnung der Koeffizienten erhalten wir:

# %%
def v_pi_cal(r_33,dr_33, r_13, dr_13):
    n = (r_33*ne**3-r_13*n0**3)
    v_pi = d/L*lambd/n
    dv_pi = v_pi/n * np.sqrt( (ne**3*dr_33)**2 + (n0**3*dr_13)**2 )
    return v_pi,dv_pi 
v_pi_c = v_pi_cal(r_33, dr_33, r_13, dr_33) 
v_pi_c_ref = v_pi_cal(r_33_ref, 0, r_13_ref, 0) 
v_pi_ref = 308 #V
display(Markdown('$V_\pi^{cal}'+'$= ({:.4} $\pm$ {:.4}) V'.format(
    v_pi_c[0], v_pi_c[1])))

display(Markdown('$V_{\pi,ref}^{cal}' + '$= ({:.4} $\pm$ {:.4}) V'.format(
    v_pi_c_ref[0], v_pi_c_ref[1])))
# Out:
# $V_\pi^{cal}$= (676.6 $\pm$ 996.1) V
# $V_{\pi,ref}^{cal}$= (281.0 $\pm$ 0.0) V

# %% [markdown]
# At this point we have estimated $V_\pi$ three times. The first values is given by the mean of the estiamted measured values $U_{pi,e}$ and $U_{pi,o}$
# $$U_{\pi}^{cal'} = (291.5 \pm 7.7e+01) V.$$
# The second values is given by the mean value of the fit parameters of the intensity transmittance:
# $$V_{\pi}^{cal'} = (407.1 \pm 6.4)V.$$
# Lastly we have also calculated the value for the half-wave voltage using the measured Pockels coefficients $r_{13}$ and $r_{33}$:
# $$V_{\pi}^{cal} = (676.6 \pm 99.6)V.$$
# From the specifications of the used Pockel Cell we get:
# $$V_{\pi, ref} \approx 308 V $$
#
# We find the following deviations of our values from the reference:

# %% [markdown]
# $$\sigma_{U_\pi^{cal'}} = 2.43$$
# $$\sigma_{V_\pi^{cal'}} = 16.5$$
# $$\sigma_{V_\pi^{cal}} = 3.7$$

# %% [markdown]
# Wir haben für die Berechnungen mit den Fit-Parameter der Transmission und den Koeffizienten der Pockell Cell Signifikante abweichungen, welche in der Kritischen Diskussion behandelt werden.

# %% [markdown]
# Wir haben mit den Oszilloskop einen offset bestimmt um den die Intensität und die angelegte Spannung maximal korrelieren, und legen darauf ein möglichst kleines Sinus- (oder anderes) Signal mit den gemessen Offset an. Kleine Änderungen in der Spannung korrelieren nun direkt zur Änderung der Intensität und ermöglicht die Modulation des Lichts entsprechend des Signals.
#
# Erhöhen wir den Offset, so ist es möglich den Hochpunkt des Sinussignals zu erreichen. Dort betrachten wir das eine Änderung der Spannung kaum die Intensität beeinträchtigt.
# Unter verwendung der Filterbox ist es möglich schelle Signale zu Modelieren. Ohne diese waren nur ~10Hz möglich. Bei Signalen die Stufen beinhalten sehen wir die Entladung der Kondensatoren, welche die Darstellung dieser Signale erschwert

# %% [markdown]
# ## Part 3. Acousto-optic effect

# %% [markdown]
# Der Brechungsindex eines Kristalls kann durch eine Schallwelle geändert werden. Durch die periodische Modulation der Dichte des Mediums, variiert auch der Brechungsindex periodisch.
#
# Für dünne Kristalle wirkt dieser mittels des Debye-Sears effect als ein Phasengitter. Zur Beschreibung der Reflexion dient die Bragg-Reflexion, wobei für dünne Gitter $\theta_1 + \theta_2 = 2\theta_B$ und für dicke Gitter $\theta_1 + \theta_2 = \theta_B$ gilt:
# $\sin\theta_B = \frac{1}{2}\frac{m\lambda}{\lambda_s}$
#
# Da sich die Schallwelle bewegt tritt auch der Dopplereffect auf, sodass höhere Ordnungen höhere bzw. niedrigere Frequenzen aufweisen. $\Delta\omega = 2\omega \frac{v}{c}$

# %% [markdown]
# ### Abhängigkeit des Beugungswinkels von der Frequenz
# Wir messen den Abstand zwischen unseren Maxima und erhalten den Winkel wie folgt:
# $$\alpha=\arctan\left(\frac{d}{l}\right)$$
# mit einem Fehler von:
#  $$\Delta \alpha = \sqrt{\left(\frac{\partial \alpha}{\partial l}\Delta l\right)^2+\left(\frac{\partial \alpha}{\partial d}\Delta d\right)^2}= \sqrt{\left(\frac{d}{d^2+l^2}\Delta l\right)^2 + \left(\frac{l}{d^2+l^2}\Delta d\right)^2}$$

# %%
l = 141  
delta_l = 2 

# first order
f0 = np.array([85,90,95,100,110,120,130,135]) 
delta_f0 = np.ones(8)*0.5 
dI = np.array([1.8,2.0,2.0,2.1,2.3,2.5,2.75,2.9])  
delta_dI = np.ones(8)*0.2 # [cm] 

# second order
f1 = np.array([85,90,95,100,110,120])  
delta_f1 = np.ones(6)*0.5 
dII = np.array([2.6,3.8,4,4.3,4.65,5.1]) 
delta_dII = np.ones(6)*0.2  

# calculate the angles
def alpha(l,d):
    return np.arctan(d/l)*180/(np.pi)
def delta_alpha(l,d,delta_l,delta_d):
    return np.sqrt( (d/(d**2+l**2)*delta_l)**2 + (l/(d**2+l**2)*delta_d)**2 ) *180/(np.pi)

alpha_I = alpha(l,dI)
delta_alpha_I = delta_alpha(l,dI,delta_l,delta_dI)

alpha_II = alpha(l,dII)
delta_alpha_II = delta_alpha(l,dII,delta_l,delta_dII)

poptI, pcovI = curve_fit(linear_model, f0, alpha_I, sigma=delta_alpha_I)
poptII, pcovII = curve_fit(linear_model, f1, alpha_II, sigma=delta_alpha_II)
plt.errorbar(f0, alpha_I, xerr=delta_f0, yerr=delta_alpha_I, fmt='x')
plt.plot(f0, linear_model(f0, *poptI), label='1st maximum')

plt.errorbar(f1, alpha_II, xerr=delta_f1, yerr=delta_alpha_II, fmt='x')
plt.plot(f1, linear_model(f1, *poptII), label='2nd maximum')

plt.title("Winkel zum n'ten Maximum gegen Frequenz")
plt.xlabel("Frequenz  [MHz]")
plt.ylabel("Winkel  [°]")
plt.grid()
plt.legend()
plt.show()

# %%
# fit coefficients:
print('a_I = (', np.round(poptI[0],4), "+/-", np.round(np.sqrt(pcovI[0][0]),4), '°/MHz')
print('b_I = (', np.round(poptI[1],2), "+/-", np.round(np.sqrt(pcovI[1][1]),2), '°')
print('a_II = (', np.round(poptII[0],3), "+/-", np.round(np.sqrt(pcovII[0][0]),3), '°/MHz')
print('b_II = (', np.round(poptII[1],1), "+/-", np.round(np.sqrt(pcovII[1][1]),1), '°')
# Out:
# a_I = ( 0.0084 +/- 0.0004 °/MHz
# b_I = ( 0.02 +/- 0.04 °
# a_II = ( 0.025 +/- 0.005 °/MHz
# b_II = ( -0.8 +/- 0.5 °

# %% [markdown]
# Wir haben ein lineares Verhältniss erwartet und konnten dies auch erfolgreich aus den Daten fitten.
# Frequenz und Winkel der 1. und 2. Maxima korrelieren mit den Faktoren $a_I=0.0084\pm0.0004 ^\circ /MHz$ und $a_{II}=0.025\pm 0.005 ^\circ /MHz$.

# %% [markdown]
# ### Abhängigkeit der Intensität von der Frequenz
# Wir messen die Intensität des 1. und 0. Maxima und vergleichen diese für unterschiedliche Frequenzen.

# %%
f2 = np.array([85,95,105,115,125,135,110,120]) 
delta_f2 = np.ones(8)*0.5 

U_0 = np.array([5.65,5.7,6.07,6.02,6.45,6.45,6.07,6])
delta_U_0 = np.array([0.01,0.05,0.05,0.05,0.1,0.1,0.05,0.05])
U_1 = np.array([0.470,0.052,0.038,0.148,0.040,0.003,0.080,0.255])
delta_U_1 = np.array([0.01,0.001,0.001,0.002,0.01,0.001,0.005,0.01])

I = U_1/U_0 
delta_I = np.sqrt( (delta_U_1/U_1)**2  + (delta_U_0/U_0)**2 ) 

plt.errorbar(f2, I, xerr=delta_f2, yerr=delta_I, fmt='o')
plt.title("Relative Intesität gegen Frequenz")
plt.xlabel("Frequenz [MHz]")
plt.ylabel("Intensität")
plt.grid()
plt.show()

# %% [markdown]
# Eine Korrelation ist hier nur schwer zu erkennen. Aufgrund der kleinen Werte um $125MHz$ und $135MHz$ und erhalten wir auch einen hohen relativen Fehler. Im folgenden Plot lassen wir diese Messpunkte aus.

# %%
f2_corr = np.delete(f2,[4,5])
delta_f2_corr = np.delete(delta_f2,[4,5])
print(f2_corr)
I_corr = np.delete(I,[4,5])
delta_I_corr = np.delete(delta_I,[4,5])

plt.errorbar(f2_corr, I_corr, xerr=delta_f2_corr, yerr=delta_I_corr, fmt='x')
plt.title("Korrigierte relative Intesität gegen Frequenz")
plt.xlabel("Frequenz [MHz]")
plt.ylabel("Intensität")
plt.grid()
plt.show()
# Out:
# [ 85  95 105 115 110 120]

# %% [markdown]
# Aus den Messpunkten denken wir ein trigonomterisches Verhältniss mit abnehmender Amplitude zu betrachten. Die Abnahme der Amplitude war hierbei durch die verstärkte Beugung zu erwarten.
# TODO

# %% [markdown]
# ### Abhängigkeit der Intesität von der Amplitude
# Wir Messen erneut die relative Intensität, jedoch nun in Abhängigkeit von der Amplitude des Schall-Signals an den AOM.

# %%
U_amp = np.array([0.5,0.7,0.9,1.1,1.3,1.5,1.7,2.0]) 
delta_U_amp = np.ones(8)*0.1
U_3 = np.array([6.37,6.26,5.87,5.75,5.7,5.7,5.55,5.65])
delta_U_3 = np.array([0.1,0.1,0.1,0.1,0.05,0.05,0.05,0.05])
U_4 = np.array([0.01,0.111,0.27,0.405,0.447,0.475,0.485,0.505])
delta_U_4 = np.array([0.001,0.005,0.01,0.01,0.01,0.01,0.01,0.01])

I2 = U_4/U_3 
delta_I2 = np.sqrt( (delta_U_4/U_4)**2  + (delta_U_3/U_3)**2 )

plt.errorbar(U_amp, I2, xerr=delta_U_amp, yerr=delta_I2, fmt='x')
plt.title("Relative Intensität gegen Amplitude")
plt.xlabel("Amplitude [V]")
plt.ylabel("Intensität")
plt.grid()
plt.show()

# %% [markdown]
# Die Intensität steigt mit der Amplitude und nähert sich einem Limit. Unterhalb einer Amplitude von $0.5V$ können wir keinen Effekt durch den AOM betrachten.

# %% [markdown]
# ### Berechnung der Schallgeschwindigkeit
# Mit hilfe von $\sin\theta_B=\frac{1}{2}\frac{m\lambda}{\lambda_s}$ und $v=\lambda f$ finden wir für kleine Winkel:
#
# $$ \sin\theta_B\frac{v_s}{f_s}=\frac{1}{2}m\lambda$$
# $$ \Rightarrow \quad v_s = \frac{1}{2}m\lambda\frac{f_s}{\sin\theta_B}\approx\frac{1}{2}m\lambda\frac{f_s}{\theta_B}=\frac{1}{2}m\lambda a$$
#
# $$ \Delta v_s = \frac{1}{2}m\lambda \Delta a = v_s\frac{\Delta a}{a}$$
#
# Mit einer Wellenänge von $\lambda \approx 633nm$ erhalten wir unter Betrachtung des ersten Maxima folgende Schallgeschwindigkeit:

# %%
lambd = 633*10**(-9) 
a = poptI[0]*np.pi/180*1e-6  
delta_a = np.sqrt(pcovI[0][0])*np.pi/180*1e-6  

v_s = lambd/(2*a)
delta_v_s = v_s*delta_a/a

print('v_s = ', np.round(v_s,0), '+/-', np.round(delta_v_s,0), ' m/s')
# Out:
# v_s =  2147.0 +/- 98.0  m/s

# %% [markdown]
# ### Berechnung der Wellenlänge und Gitterperiode
# Mit dieser Schallgeschwindigkeit können wir die Wellenlänge berechnen:
# $$\lambda_s=\frac{v_s}{f_s}$$
# $$ \Delta \lambda_s = \lambda_s\sqrt{\left(\frac{\Delta v_s}{v_s}\right)^2+\left(\frac{\Delta f_s}{f_s}\right)^2}$$

# %%
f3= f0*10**6   
delta_f3= delta_f0*10**6

av_lambd_s = np.mean(v_s/(f3))
delta_av_lambd_s = np.mean(v_s/f3*np.sqrt((delta_v_s/v_s)**2 + (delta_f3/f3)**2))

print('lambda_s = ', np.round(av_lambd_s,7), '+/-', np.round(delta_av_lambd_s,7), 'm')
# Out:
# lambda_s =  2.04e-05 +/- 9e-07 m

# %% [markdown]
# Wir erhalten eine Wellenlänge von $\lambda_s = (20.4\pm0.9)\mu m$.
#
# Mit dem $L$ aus dem Skript können wir nun die Gitterkonstante berechnen:
# $$n=\frac{L}{\lambda_s}$$
# $$  \Delta n = n\frac{\Delta \lambda_s}{\lambda_s}$$

# %%
L = 20 

n = L*10**(-3)/(av_lambd_s) 
delta_n = n*delta_av_lambd_s/av_lambd_s

print('n =', np.round(n,0), '+-', np.round(delta_n,0))
# Out:
# n = 982.0 +- 45.0

# %% [markdown]
# ### Berechnung der Schallleistung bei optimaler Ablenkungseffizienz.
# Für die Schallleistung können wir die Gleichung (3.4) aus dem Skript nutzen.
# $$ R= \sin^2\left(\frac{\pi L}{\lambda \cos \theta_B}\sqrt{\frac{M_2 I_s}{2}}\right) $$
# Bei einer optimalen Ablenkungseffizienz gilt $R=1$ und $\cos(\theta_B)=1$, sodass
# $$\frac{\pi}{2}=\frac{\pi L}{\lambda \cos \theta_B}\sqrt{\frac{M_2 I_s}{2}}$$
# $$\Rightarrow I_s = \dfrac{\lambda^2}{2\,L^2\, M_2}$$
# Die Schallleistung $P$ ergibt sich aus $I_s$ und der Fläche $A$
# $$P=A I_s = L h I_s = L  h \, \dfrac{\lambda^2}{2\,L^2\, M_2} = \dfrac{h\lambda^2}{2\,L\, M_2} $$

# %%
h = 3e-3        
M_2 = 34.5e-15  

P_s = h*lambd**2/(2*(L*10**(-3))*M_2)

print('P_s =', P_s, 'W')
# Out:
# P_s = 0.8710630434782609 W

# %% [markdown]
# ### Optimale Frequenz der AOM
# Die optimale Frequenz wurde aus der dritten Tabelle im Protokoll abgelesen. Sie wurde aus der größten Spannung an der Fotodiode im ersten Maximum ermittelt. Wir haben einen Wert von 120 Hz ermittelt. Dieser Wert hängt natürlich vom verwendeten AOM ab.

# %% [markdown]
# Durch die Modulation der Frequenz über eine Amplitudenmodulation ändern sich die Abstände der Interferenzen gemäß der Frequenz durch die Phasenverschiebung der beiden Signale schwingen diese gegeneinander. Je nach Amplitude des generierten Signals erhalten wir ein elliptisches oder circuläres Muster. Bei hoher Frequenzen ist die Modulation der Interferenzen mit bloßen Auge nicht mehr differenzierbar.
#
# Die Beugung des 1. Nebenmaxima beweegt sich entsprechend der XY Darstellung dunseres Signales. Diese können also sowohl im Vergleich des Funktionsgeneratorsignal, als auch als Interferenzmuster betrachtet werden.
#
# Für niedrige Frequenzen ist die Bewegung mit boßem Auge zu differenzieren, diese folgt im Falle eines Sinussignales gleicher Frequenz einer ellypse wobei die Phase die...

# %% [markdown]
# Für ein Sinussignal haben wir ohne Phasenverschiebung lediglich eine Diagonale erhalten. Für eine Phasenverschiebung von $90^\circ$ würden wir nun ein zyrkuläres Signal erwarten, da dies einem Plot von Sinus gegen Kosinus entspricht. Tatsächlich beobachten wir auch dies. Für eine Phasenverschiebung von $180^\circ$ erhalten wir erneut eine Diagonale, jedoch mit negativer Steigung. Für ein Rechteckiges Signal sind lediglich die Kanten Sichtbar, also zwischen 2 und 4 Punkten, welche für ein dreieckiges Signal auch verbunden sind. Hier erhalten wir ein lineares oder rautenförmiges Beugungsbild in $d_{1,1}.
#
# Die Beugungsbilder in $d_{1,1}$ , $d_{1,2}$ und $d_{2,2}$ zeigen alle die selbe Struktur, werden jedoch in ihre jeweilige Achse gedehnt.
#
# Die Manipulation von unpolarisiertem Licht durch die beiden AOM ist mit der Manipulation durch Polifilter und Wave Plates zu vergleichen, wobei hier Brechungsbilder durch die Modulation von Brechungsindexen und nicht die geziehlte Behandlung von Polarisierung geschieht.
#
# Die Phasenverschiebung von $0^\circ$ - $90^\circ$ usw. stellt eine Verschiebung von linear zu elliptisch zu zirkulär polarisiertem Licht dar, und ist somit analog zum Verhalten einer Quarter Wave Plate.
#
# Wird eine Frequenz als vielfache der anderen gewählt, so erhalten wir komplexere, symmetrische Muster, da wir mehrere vollständige Perioden während einer Periode der anderen Richtung erhalten. Für andere vielfache ist das Muster unregelmässig. Phasendifferenz ist stabil sofern wir keine änderung unseres Beugungsmusters über die Zeit betrachten.

# %% [markdown]
# ## Kritische Diskussion
# In diesem Versuch haben wir uns mit der Manipulation von Licht mittels optischer Medien beschäftigt. Einerseits habe wir das Verhalten dieses über dessen Polirisation manipuliert, andererseits über die Transmissin durch Medien mit variablen Brechungsindexen. Diese wurden durch elektromagnetische Felder, sowie angelegte Schallwellen manipuliert.
#
# Im ersten Teil behandelten wir uns explizit mit der Polarisation. Wir haben die Polarisation unserer Quelle überprüft, welche linear horizontal Polarisiert war. Darauf haben wir weitere optische Bauteile wie (P)BS und Wave Plates betrachtet und dessen auswirkung auf die Art der Polaristion und Phase des Lichts betrachtet.
# Einige unserer Beobachtungen haben wir zur Zeit des Versuches falsch interpretiert, was wir bei der Auswertung an den entsprechenden Stellen jedoch kommetiert hatten.
# Leider sind uns beim Experimentieren hier vermutlich auch einige Fehler eingegangen, wie z.B die verwendung der falschen Wave Plate, oder Polifilter bei denen die Achsenbeschriftung von der tatsächlichen Ausrichtung des Filters abwiech.
#
#
#
#
# Im zweiten Teil behandelten wir EOM. Wir haben die Verstärkung unserer Hochspannungsquelle bestimmt, sodass wir unsere Pockly Cell nicht beschädigen. Mit einer Vertärkung von $300$ haben wir eine angelegte Spannung von $6,1V$ nicht überschritten. Darauf konstruierten wir ein Mach-Zehnder Interferometer und haben die Intensität in abhängigkeit der angelegten Spannung an die Pockel Cell für $\pm 45^\circ$ und $\pm 90^\circ$ aufgenommen. Aus diesen Messwerten Versuchten wir die half-wave Spannung $U_\pi$ der Kristallaxen zu bestimmen, sowie die Koeffizienten $r_{1,3}$ und $r_{3,3}$.
#
# Aus der $90^\circ$ Messung haben wir eine half wave Spannung von $U_\pi = \left(291,5\pm 77,0\right)V$ erhalten, sowie die Koeffizienten $r_{1,3}=\left(1.41\pm0.25\right)m/V$ und $r_{3,3}=\left(2.6\pm0.8\right)m/V$
#
# Aus dem Fit der Transmission haben wir einen Wert von $U_\pi = \left(407.1\pm 6.4\right)V$ was signifikant von den erwarteten $308V$, mit einem Sigma von $16.5\sigma$ abweicht. Auch der Wert aus den Koeffizienten $r_{1,3}$ und $r_{3,3}$ mit $U_\pi = \left(676.6\pm 99.6\right)V$ weicht signifikant ab.

# %% [markdown]
# Zuletzt haben wir hier die lineare Modulation der Amplitude betrachtet. Hier konnten wir durch die Wahl einer geeigneten Offset-Spannung beliebige Signale optisch durch Modulation des Brechungsindexes darstellen.

# %% [markdown]
# Im dritten Teil haben wir uns mit AOM beschäftigt. Wir haben die Auswirkung eines AOM in Bezug auf Brechungswinkel und Intensität in Abhängigkeit der Frequenz betrachtet und konnten für den Winkel die Faktoren $a_I=0.0084\pm0.0004 ^\circ /MHz$ und $a_{II}=0.025\pm 0.005 ^\circ /MHz$ bestimmen. In der Intensität fand sich wohmöglich eine abnehmende, oszillierendes Verhältniss, was jedoch mit der Messreihe nicht eindeutig ist.
# Mit der Zuhname der Amplitude nimmt auch die Intensität unserer Maxima zu.
# Die Messung der Intensität fand hierbei stets relativ statt. Also wurde das Nebenmaxima gegen das Hauptmaxima gemessen. Hierbei mussten jedoch Polifiter genutzt werden, um die Intensität ohne Sättigung zu Messen. Dies in Kombination mit der regelmässigen Rejustierung der Diode, aufgrund der Winkeländerung hat uns die Messung deutlich erschwert, und stellt eine grosse Quelle für Inkonsistenz dar.
#
# Zuletzt fürten wir einen zweiten AOM ein und Modulierten die Spannung beider simultan. Sodass wir folglich Modulation im Beugungsbild betrachten konnten, welche der Darstellung der angelegten Spannungen entsprach.
